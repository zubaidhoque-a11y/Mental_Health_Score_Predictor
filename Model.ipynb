# %% [markdown]
# # Mental health Predictor by Jubaid

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Student Social Media And Mental Health Impact.csv")

# %%
df.head()
# Out:
#    Age  Gender Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0   21    Male   Other  Undergraduate           Facebook     Networking
# 1   23  Female   Other       Graduate           LinkedIn      Education
# 2   22    Male  Canada  Undergraduate          Instagram  Entertainment
# 3   18    Male   Other    High School           Snapchat  Entertainment
# 4   24  Female   Other       Graduate           Facebook     Networking
#
#    Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  Physical_Activity_Hours  \
# 0                    4.0            134          4.5                      2.2
# 1                    1.6             73          7.0                      2.4
# 2                    4.6            166          4.0                      1.8
# 3                    7.0            220          1.0                      1.7
# 4                    7.5            237          1.0                      1.1
#
#    Sleep_Hours_Per_Night Stress_Level  Mental_Health_Score
# ...

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.isnull().sum()
# Out:
# Age                        0
# Gender                     0
# Country                    0
# Academic_Level             0
# Most_Used_Platform         0
# Purpose_Of_Use             0
# Avg_Daily_Usage_Hours      0
# Daily_Unlocks              0
# Study_Hours                0
# Physical_Activity_Hours    0
# Sleep_Hours_Per_Night      0
# Stress_Level               0
# Mental_Health_Score        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.describe()
# Out:
#               Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  5000.00000            5000.000000    5000.000000  5000.000000
# mean     20.82180               5.078460     171.452600     3.008420
# std       1.73662               1.653913      42.858254     1.637018
# min      18.00000               1.000000      62.000000     0.300000
# 25%      19.00000               3.800000     140.000000     1.500000
# 50%      21.00000               5.000000     171.000000     2.800000
# 75%      22.00000               6.300000     204.000000     4.200000
# max      24.00000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              5000.000000            5000.000000          5000.000000
# mean                  1.751000               6.634580             6.230980
# std                   0.668398               1.221391             1.278701
# ...

# %% [markdown]
# ** Physical activity Hours the min value -4 therefore we have to clean in the data cleaning step

# %% [markdown]
# # EDA

# %%
sns.histplot(df['Mental_Health_Score'] , kde = True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Mental_Health_Score', ylabel='Count'>

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df['Stress_Level'].unique()
# Out:
# array(['Medium', 'Low', 'Very High', 'High'], dtype=object)

# %%
order = ['Low', 'Medium' , 'High', 'Very High']
sns.boxplot(x = 'Stress_Level', y= "Mental_Health_Score", data =df , order =order )
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Mental_Health_Score'>

# %% [markdown]
# Daily usage hour vs mental health score

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Country', 'Academic_Level', 'Most_Used_Platform',
#        'Purpose_Of_Use', 'Avg_Daily_Usage_Hours', 'Daily_Unlocks',
#        'Study_Hours', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night',
#        'Stress_Level', 'Mental_Health_Score'],
#       dtype='object')

# %%
sns.scatterplot(x='Avg_Daily_Usage_Hours', y= 'Mental_Health_Score', data =df)
# Out:
# <Axes: xlabel='Avg_Daily_Usage_Hours', ylabel='Mental_Health_Score'>

# %%
sns.scatterplot(x='Sleep_Hours_Per_Night', y= 'Mental_Health_Score', data =df)
# Out:
# <Axes: xlabel='Sleep_Hours_Per_Night', ylabel='Mental_Health_Score'>

# %%
df['Most_Used_Platform'].value_counts()
# Out:
# Most_Used_Platform
# Instagram    1130
# TikTok        918
# Facebook      719
# LinkedIn      523
# YouTube       491
# Twitter       462
# Snapchat      420
# WhatsApp      175
# LINE           50
# VKontakte      40
# KakaoTalk      36
# WeChat         36
# Name: count, dtype: int64

# %%
sns.countplot(x = df['Most_Used_Platform'], order =df['Most_Used_Platform'].value_counts().index)
# Out:
# <Axes: xlabel='Most_Used_Platform', ylabel='count'>

# %% [markdown]
# #Checking Outliers

# %%
num_features = df.select_dtypes(include='number')
num_features
# Out:
#       Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# 0      21                    4.0            134          4.5
# 1      23                    1.6             73          7.0
# 2      22                    4.6            166          4.0
# 3      18                    7.0            220          1.0
# 4      24                    7.5            237          1.0
# ...   ...                    ...            ...          ...
# 4995   18                    1.9             89          6.1
# 4996   18                    6.6            216          2.3
# 4997   19                    3.8            151          5.4
# 4998   18                    3.8            119          4.0
# 4999   19                    5.4            177          1.2
#
#       Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# 0                         2.2                    6.7                  6.8
# 1                         2.4                    8.6                  7.6
# ...

# %%
Q1 = num_features.quantile(0.25)
Q3 = num_features.quantile(0.75)
IQR = Q3-Q1

lower_bound = Q1 -1.5 *IQR
upper_bound = Q3 +1.5 *IQR

# %%
outliers = (num_features<lower_bound) | (num_features>upper_bound)

# %% [markdown]
# **Data Cleaning**

# %%
#Droping the duplicates 
df =df.drop_duplicates()

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  4998.000000            4998.000000    4998.000000  4998.000000
# mean     20.822129               5.078491     171.455582     3.008403
# std       1.736774               1.654097      42.859829     1.636831
# min      18.000000               1.000000      62.000000     0.300000
# 25%      19.000000               3.800000     140.000000     1.500000
# 50%      21.000000               5.000000     171.000000     2.800000
# 75%      22.000000               6.300000     204.000000     4.200000
# max      24.000000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              4998.000000            4998.000000          4998.000000
# mean                  1.750760               6.634654             6.231152
# std                   0.668406               1.221561             1.278476
# ...

# %%
#converting unrealistic negative values to realistic one
df['Physical_Activity_Hours']= df['Physical_Activity_Hours'].clip(lower =0)

# %%
df.describe()
# Out:
#                Age  Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# count  4998.000000            4998.000000    4998.000000  4998.000000
# mean     20.822129               5.078491     171.455582     3.008403
# std       1.736774               1.654097      42.859829     1.636831
# min      18.000000               1.000000      62.000000     0.300000
# 25%      19.000000               3.800000     140.000000     1.500000
# 50%      21.000000               5.000000     171.000000     2.800000
# 75%      22.000000               6.300000     204.000000     4.200000
# max      24.000000               8.800000     273.000000     8.300000
#
#        Physical_Activity_Hours  Sleep_Hours_Per_Night  Mental_Health_Score
# count              4998.000000            4998.000000          4998.000000
# mean                  1.751160               6.634654             6.231152
# std                   0.667282               1.221561             1.278476
# ...

# %% [markdown]
# # **Skewness**

# %%
num_cols = df.select_dtypes(include = 'number')
num_cols.skew()
# Out:
# Age                        0.155008
# Avg_Daily_Usage_Hours      0.005575
# Daily_Unlocks              0.002309
# Study_Hours                0.436125
# Physical_Activity_Hours    0.053288
# Sleep_Hours_Per_Night      0.123919
# Mental_Health_Score        0.207086
# dtype: float64

# %% [markdown]
# # **Feature Engineering**

# %%
top_country = df['Country'].value_counts().index[:10] .tolist()
top_country
# Out:
# ['Other',
#  'India',
#  'USA',
#  'Canada',
#  'Australia',
#  'UK',
#  'Germany',
#  'Turkey',
#  'Mexico',
#  'France']

# %%
df['Country'].value_counts()
# Out:
# Country
# Other        1879
# India         389
# USA           354
# Canada        230
# Australia     198
#              ...
# Armenia         1
# Kuwait          1
# Colombia        1
# Bosnia          1
# Croatia         1
# Name: count, Length: 111, dtype: int64

# %%
def group_country(country):
    if country in top_country:
        return country 
    else:
        return 'Other'

# %%
df['Group_country']= df['Country'].apply(group_country)

# %%
df
# Out:
#       Age  Gender Country Academic_Level Most_Used_Platform Purpose_Of_Use  \
# 0      21    Male   Other  Undergraduate           Facebook     Networking
# 1      23  Female   Other       Graduate           LinkedIn      Education
# 2      22    Male  Canada  Undergraduate          Instagram  Entertainment
# 3      18    Male   Other    High School           Snapchat  Entertainment
# 4      24  Female   Other       Graduate           Facebook     Networking
# ...   ...     ...     ...            ...                ...            ...
# 4995   18  Female   Other    High School            YouTube      Education
# 4996   18  Female   Other    High School            YouTube      Education
# 4997   19  Female   India  Undergraduate           LinkedIn      Education
# 4998   18    Male   Other    High School          Instagram  Entertainment
# 4999   19    Male   China  Undergraduate             WeChat  Entertainment
#
#       Avg_Daily_Usage_Hours  Daily_Unlocks  Study_Hours  \
# ...

# %%
from sklearn.model_selection import train_test_split
#Log Transformation
skewed_cols =['Study_Hours']
#Standard Scaler
other_numeric_cols = ['Avg_Daily_Usage_Hours', 'Daily_Unlocks', 'Physical_Activity_Hours', 'Sleep_Hours_Per_Night', 'Age']

#Label Encoding
ordinal_cols = ['Stress_Level']
#One Hot Encoding
nominal_cols = ['Gender', 'Academic_Level', 'Most_Used_Platform', 'Purpose_Of_Use', 'Group_country']

feature_col = skewed_cols + other_numeric_cols + ordinal_cols + nominal_cols
X= df[feature_col]
y = df['Mental_Health_Score']

X_train,X_test,y_train,y_test= train_test_split(X,y, test_size =0.30, random_state=42)

# %% [markdown]
# # **Pipelines for Preprocessing(scaling and encoding and all)**

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer , StandardScaler, OrdinalEncoder,OneHotEncoder
#Skewed Features
skew_pipeline = Pipeline(steps= [
    ('log_transform', FunctionTransformer(np.log1p)),
    ('scale', StandardScaler())

])

#Numeric features
plain_numeric_pipeline = Pipeline(steps=[
    ('scale', StandardScaler())
])

#Label Encoding Features

ordinal_pipeline = Pipeline(steps=[
    ('encode', OrdinalEncoder(categories=[['Low', 'Medium', 'High', 'Very High']]))
])

#One hod encoding features 

nominal_pipeline = Pipeline(steps=[
    ('encode', OneHotEncoder(handle_unknown='ignore'))
])

# %% [markdown]
# **Put the dedicated columns into the required Pipeline**

# %%
from sklearn.compose import ColumnTransformer

#(kaunsi_pipeline, kaunsi_features)
preprocessor = ColumnTransformer(transformers=[
    ("Skewed_Pipeline", skew_pipeline, skewed_cols),
    ("Plain_Numeric",plain_numeric_pipeline, other_numeric_cols ),
    ('Ordinal', ordinal_pipeline, ordinal_cols),
    ('Normal', nominal_pipeline, nominal_cols)
])

# %% [markdown]
# # **Pipelines for Model Selection**

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

lr_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

lr_pipeline.fit(X_train, y_train)
lr_preds       = lr_pipeline.predict(X_test)
lr_preds_train = lr_pipeline.predict(X_train)

lr_r2_testing  = r2_score(y_test, lr_preds)
lr_r2_training = r2_score(y_train, lr_preds_train)
lr_mae         = mean_absolute_error(y_test, lr_preds)


print(f"Accuracy of Training {lr_r2_training}")
print(f"Accuracy of Testing {lr_r2_testing}")
print(f'MAE {lr_mae}')
# Out:
# Accuracy of Training 0.7236771199387539
# Accuracy of Testing 0.7397944617433021
# MAE 0.5361775634720182

# %%
from sklearn.ensemble import RandomForestRegressor
rf_pipeline = Pipeline(steps=[
    ('preprocessor' , preprocessor),
    ('RandomForest',RandomForestRegressor(random_state=42))
])

rf_pipeline.fit(X_train,y_train)
rf_preds = rf_pipeline.predict(X_test)
rf_preds_train = rf_pipeline.predict(X_train)

rf_r2_testing = r2_score(y_test,rf_preds)
rf_r2_training = r2_score(y_train,rf_preds_train)
mae = mean_absolute_error(y_test, rf_preds)

print(f"Accuracy of Training {rf_r2_training}")
print(f"Accuracy of Testing {rf_r2_testing}")
print (mae)
# Out:
# Accuracy of Training 0.9807874883367435
# Accuracy of Testing 0.8773227123804905
# 0.3480292000000001

# %% [markdown]
# **Hyperparameter tuning the Random Forest to decrease the accuracy gap between training and testing**

# %%
from sklearn.model_selection import RandomizedSearchCV
param_grid = {
    'RandomForest__n_estimators': [100, 200, 300],     
    'RandomForest__max_depth': [5, 10, 15],            
    'RandomForest__min_samples_split': [2, 5, 10],     
    'RandomForest__min_samples_leaf': [1, 2, 4]        
}
random_search =RandomizedSearchCV(
    estimator = rf_pipeline,
    param_distributions=param_grid,
    n_iter = 15,
    cv= 5,
    scoring ='r2',
    random_state = 42,
    n_jobs= -1
)
random_search.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('Skewed_Pipeline',
#                                                                                Pipeline(steps=[('log_transform',
#                                                                                                 FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                                                ('scale',
#                                                                                                 StandardScaler())]),
#                                                                                ['Study_Hours']),
#                                                                               ('Plain_Numeric',
#                                                                                Pipeline(steps=[('scale',
# ...

# %%
random_search.best_params_
# Out:
# {'RandomForest__n_estimators': 200,
#  'RandomForest__min_samples_split': 5,
#  'RandomForest__min_samples_leaf': 2,
#  'RandomForest__max_depth': 15}

# %%
rf_best_pipeline=  random_search.best_estimator_
rf_best_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('Skewed_Pipeline',
#                                                   Pipeline(steps=[('log_transform',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['Study_Hours']),
#                                                  ('Plain_Numeric',
#                                                   Pipeline(steps=[('scale',
#                                                                    StandardScaler())]),
#                                                   ['Avg_Daily_Usage_Hours',
#                                                    'Daily_Unlocks',
# ...

# %%
rf_best_preds = rf_best_pipeline.predict(X_test)
print(f"The R2 score of the random forest after hyperparameter tuning is: {r2_score (y_test, rf_best_preds)}")
# Out:
# The R2 score of the random forest after hyperparameter tuning is: 0.8652033937965293

# %% [markdown]
# # **Exporting the file for FastAPI

# %%
import joblib
joblib.dump(rf_pipeline, "Mental_Health_Model.pkl")
# Out:
# ['Mental_Health_Model.pkl']

# %%
pip scikit-learn
# Out:
# ERROR: unknown command "scikit-learn"
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.9.1
# Summary: A set of python modules for machine learning and data mining
# Home-page:
# Author:
# Author-email:
# License:
# Location: /opt/anaconda3/lib/python3.11/site-packages
# Requires: joblib, narwhals, numpy, scipy, threadpoolctl
# Required-by: imbalanced-learn
# Note: you may need to restart the kernel to use updated packages.
